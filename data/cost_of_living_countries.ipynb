# %%
import pandas as pd
import numpy as np

# %%
import os

cwd = os.getcwd()
col_path = os.path.join(cwd, "raw/cost_of_living_countries.csv")
country_codes_path = os.path.join(cwd,"raw/ISO-3166-Countries-with-Regional-Code.csv")

# %%
col = pd.read_csv(col_path)
print(col.head())
len(col)
# Out:
#    Rank      Country  Cost of Living Index  Rent Index  \
# 0     1      Ireland                 126.1        85.9
# 1     2  Netherlands                 123.8        71.9
# 2     3       France                 120.9        77.7
# 3     4      Belgium                 117.5        78.8
# 4     5       Sweden                 112.5        33.3
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           110.1            154.5                   131.6
# 1                           103.2             90.1                   108.5
# 2                           103.8            115.4                   118.3
# 3                           102.2            110.9                   107.6
# 4                            81.1             99.0                    85.2
#
#    Local Purchasing Power Index  Year
# 0                          59.8  2009
# 1                          41.6  2009
# 2                          45.5  2009
# 3                          55.6  2009
# 4                          62.8  2009
# 3323

# %%
col['Country'] = col['Country'].str.replace(r'\s*\(.*?\)', '', regex=True)
col['Country'] = col['Country'].str.replace(r'\bAnd\b', 'and', regex=True)
col['Country'] = col['Country'].str.replace(r'\bOf\b', 'of', regex=True)


#convert mid-years to June of the same year
def convert_to_date(year_str):
    if 'Mid-Year' in year_str:
        return pd.to_datetime(year_str.replace('Mid-Year', ' June'), format='%Y %B')
    else:
        return pd.to_datetime(year_str, format='%Y')

col['Year'] = col['Year'].apply(convert_to_date)

# %%
country_codes = pd.read_csv(country_codes_path)
print(country_codes.head())
len(country_codes)
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 249

# %%
# rename some country names:
country_codes.replace(to_replace="Türkiye", value="Turkey",inplace=True)
country_codes.replace(to_replace="United Kingdom of Great Britain and Northern Ireland", value="United Kingdom",inplace=True)
country_codes.replace(to_replace="United States of America", value="United States",inplace=True)
country_codes.replace(to_replace="Russian Federation", value="Russia",inplace=True)
country_codes.replace(to_replace="Netherlands, Kingdom of the", value="Netherlands",inplace=True)
country_codes.replace(to_replace="Czechia", value="Czech Republic",inplace=True)
country_codes.replace(to_replace="Iran, Islamic Republic of", value="Iran",inplace=True)
country_codes.replace(to_replace="Korea, Democratic People's Republic of", value="North Korea",inplace=True)
country_codes.replace(to_replace="Korea, Republic of", value="South Korea",inplace=True)
country_codes.replace(to_replace="Viet Nam", value="Vietnam",inplace=True)
country_codes.replace(to_replace="Taiwan, Province of China", value="Taiwan",inplace=True)
country_codes.replace(to_replace="Tanzania, United Republic of", value="Tanzania",inplace=True)
country_codes.replace(to_replace="Côte d'Ivoire", value="Ivory Coast",inplace=True)
country_codes.replace(to_replace="Syrian Arab Republic", value="Syria",inplace=True)
country_codes.replace(to_replace="Congo, Democratic Republic of the", value="Democratic Republic of the Congo",inplace=True)
country_codes.replace(to_replace="Lao People's Democratic Republic", value="Laos",inplace=True)
country_codes.replace(to_replace="Bolivia, Plurinational State of", value="Bolivia",inplace=True)
country_codes.replace(to_replace="Falkland Islands (Malvinas)", value="Falkland Islands",inplace=True)
country_codes.replace(to_replace="Venezuela, Bolivarian Republic of", value="Venezuela",inplace=True)
country_codes.replace(to_replace="Moldova, Republic of", value="Moldova",inplace=True)
country_codes.replace(to_replace="Brunei Darussalam", value="Brunei",inplace=True)
country_codes.replace(to_replace="Palestine, State of", value="Palestine",inplace=True)
country_codes.replace(to_replace="Virgin Islands (U.S.)", value="Us Virgin Islands",inplace=True)

# %%
col_with_country_codes = col.merge(country_codes, left_on='Country', right_on='name', how='left')

# %%
# there should not be any null values
nan_rows = col_with_country_codes[col_with_country_codes['alpha-2'].isnull()]
#Kosovo does not have ISO code
#Namibia alpha-2 code for some reason does not work properly
nan_rows
# Out:
#       Rank  Country  Cost of Living Index  Rent Index  \
# 430     58  Namibia                  59.8        24.3
# 550     65  Namibia                  53.7        20.7
# 588    103   Kosovo                  40.2        14.8
# 688     84  Namibia                  39.7        16.7
# 795     69  Namibia                  46.5        21.0
# 956    109   Kosovo                  29.4         8.6
# 1028    66  Namibia                  43.2        17.5
# 1077   115   Kosovo                  26.2         8.1
# 1152    71  Namibia                  43.1        16.1
# 1205   124   Kosovo                  28.5         8.5
# 1296    83  Namibia                  41.0        14.3
# 1339   126   Kosovo                  29.4         8.8
# 1485   134   Kosovo                  27.1         8.0
# 1585    95  Namibia                  35.8        11.8
# 1613   123   Kosovo                  28.4         8.0
# 1739   109   Kosovo                  31.3         8.5
# 1742   112  Namibia                  30.8        10.4
# 1884   108  Namibia                  29.3        11.4
# 1894   118   Kosovo                  25.7         6.7
# 1966    51  Namibia                  63.7        26.3
# 2092    58  Namibia                  52.1        18.3
# 2154   120   Kosovo                  30.4         8.6
# 2240    81  Namibia                  40.7        18.9
# 2392   110   Kosovo                  29.7         8.1
# 2455    58  Namibia                  45.5        18.3
# 2510   113   Kosovo                  26.7         7.7
# 2588    74  Namibia                  44.1        16.9
# 2643   129   Kosovo                  27.4         8.7
# 2741    91  Namibia                  38.1        12.5
# 2777   127   Kosovo                  28.4         8.5
# 2920   135   Kosovo                  27.8         8.8
# 3010    86  Namibia                  35.6        11.6
# 3056   132   Kosovo                  25.2         6.9
# 3173   112  Namibia                  31.4        10.6
# 3183   122   Kosovo                  29.5         8.0
# 3298    97   Kosovo                  29.5         7.7
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 430                             42.6             52.7                    47.8
# 550                             37.5             46.7                    51.4
# 588                             27.7             30.5                    29.7
# 688                             28.7             32.7                    35.7
# 795                             34.3             40.9                    43.2
# 956                             19.4             26.3                    21.0
# 1028                            30.8             39.9                    38.6
# 1077                            17.5             23.2                    19.6
# 1152                            30.2             36.8                    39.2
# 1205                            18.9             26.5                    21.0
# 1296                            28.2             35.7                    35.6
# 1339                            19.6             26.9                    21.1
# 1485                            18.1             24.8                    19.5
# 1585                            24.3             30.9                    39.1
# 1613                            18.6             25.1                    19.6
# 1739                            20.5             29.3                    20.7
# 1742                            21.1             30.0                    27.4
# 1884                            21.4             31.3                    28.9
# 1894                            17.3             27.1                    20.9
# 1966                            45.7             58.5                    53.8
# 2092                            34.9             41.2                    50.8
# 2154                            19.3             25.0                    24.6
# 2240                            30.5             35.4                    38.8
# 2392                            19.1             27.0                    21.2
# 2455                            32.6             40.4                    40.6
# 2510                            17.7             22.6                    19.9
# 2588                            31.1             38.9                    41.2
# 2643                            18.5             24.6                    21.1
# 2741                            25.7             31.8                    36.6
# 2777                            18.7             26.6                    19.5
# 2920                            19.0             25.3                    20.9
# 3010                            24.2             33.0                    37.4
# 3056                            16.5             23.5                    15.9
# 3173                            21.5             28.2                    31.5
# 3183                            19.3             26.3                    20.7
# 3298                            19.0             29.4                    20.6
#
#       Local Purchasing Power Index       Year     name alpha-2 alpha-3  \
# 430                           35.0 2014-01-01  Namibia     NaN     NAM
# 550                           42.9 2015-01-01  Namibia     NaN     NAM
# 588                           29.2 2015-01-01      NaN     NaN     NaN
# 688                           49.2 2016-01-01  Namibia     NaN     NAM
# 795                           50.5 2017-01-01  Namibia     NaN     NAM
# 956                           59.2 2018-01-01      NaN     NaN     NaN
# 1028                          63.6 2019-01-01  Namibia     NaN     NAM
# 1077                          61.8 2019-01-01      NaN     NaN     NaN
# 1152                          55.6 2020-01-01  Namibia     NaN     NAM
# 1205                          48.9 2020-01-01      NaN     NaN     NaN
# 1296                          53.3 2021-01-01  Namibia     NaN     NAM
# 1339                          40.1 2021-01-01      NaN     NaN     NaN
# 1485                          43.9 2022-01-01      NaN     NaN     NaN
# 1585                          51.3 2023-01-01  Namibia     NaN     NAM
# 1613                          37.6 2023-01-01      NaN     NaN     NaN
# 1739                          34.8 2024-01-01      NaN     NaN     NaN
# 1742                          51.4 2024-01-01  Namibia     NaN     NAM
# 1884                          62.2 2025-01-01  Namibia     NaN     NAM
# 1894                          52.9 2025-01-01      NaN     NaN     NaN
# 1966                          40.3 2014-06-01  Namibia     NaN     NAM
# 2092                          58.5 2015-06-01  Namibia     NaN     NAM
# 2154                          64.6 2015-06-01      NaN     NaN     NaN
# 2240                          51.8 2016-06-01  Namibia     NaN     NAM
# 2392                          49.4 2017-06-01      NaN     NaN     NaN
# 2455                          60.3 2018-06-01  Namibia     NaN     NAM
# 2510                          61.4 2018-06-01      NaN     NaN     NaN
# 2588                          60.2 2019-06-01  Namibia     NaN     NAM
# 2643                          54.1 2019-06-01      NaN     NaN     NaN
# 2741                          58.1 2020-06-01  Namibia     NaN     NAM
# 2777                          43.3 2020-06-01      NaN     NaN     NaN
# 2920                          39.1 2021-06-01      NaN     NaN     NaN
# 3010                          51.0 2022-06-01  Namibia     NaN     NAM
# 3056                          38.9 2022-06-01      NaN     NaN     NaN
# 3173                          47.7 2023-06-01  Namibia     NaN     NAM
# 3183                          34.2 2023-06-01      NaN     NaN     NaN
# 3298                          46.7 2024-06-01      NaN     NaN     NaN
#
#       country-code     iso_3166-2  region          sub-region  \
# 430          516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 550          516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 588            NaN            NaN     NaN                 NaN
# 688          516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 795          516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 956            NaN            NaN     NaN                 NaN
# 1028         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1077           NaN            NaN     NaN                 NaN
# 1152         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1205           NaN            NaN     NaN                 NaN
# 1296         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1339           NaN            NaN     NaN                 NaN
# 1485           NaN            NaN     NaN                 NaN
# 1585         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1613           NaN            NaN     NaN                 NaN
# 1739           NaN            NaN     NaN                 NaN
# 1742         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1884         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 1894           NaN            NaN     NaN                 NaN
# 1966         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2092         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2154           NaN            NaN     NaN                 NaN
# 2240         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2392           NaN            NaN     NaN                 NaN
# 2455         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2510           NaN            NaN     NaN                 NaN
# 2588         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2643           NaN            NaN     NaN                 NaN
# 2741         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 2777           NaN            NaN     NaN                 NaN
# 2920           NaN            NaN     NaN                 NaN
# 3010         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 3056           NaN            NaN     NaN                 NaN
# 3173         516.0  ISO 3166-2:NA  Africa  Sub-Saharan Africa
# 3183           NaN            NaN     NaN                 NaN
# 3298           NaN            NaN     NaN                 NaN
#
#      intermediate-region  region-code  sub-region-code  \
# 430      Southern Africa          2.0            202.0
# 550      Southern Africa          2.0            202.0
# 588                  NaN          NaN              NaN
# 688      Southern Africa          2.0            202.0
# 795      Southern Africa          2.0            202.0
# 956                  NaN          NaN              NaN
# 1028     Southern Africa          2.0            202.0
# 1077                 NaN          NaN              NaN
# 1152     Southern Africa          2.0            202.0
# 1205                 NaN          NaN              NaN
# 1296     Southern Africa          2.0            202.0
# 1339                 NaN          NaN              NaN
# 1485                 NaN          NaN              NaN
# 1585     Southern Africa          2.0            202.0
# 1613                 NaN          NaN              NaN
# 1739                 NaN          NaN              NaN
# 1742     Southern Africa          2.0            202.0
# 1884     Southern Africa          2.0            202.0
# 1894                 NaN          NaN              NaN
# 1966     Southern Africa          2.0            202.0
# 2092     Southern Africa          2.0            202.0
# 2154                 NaN          NaN              NaN
# 2240     Southern Africa          2.0            202.0
# 2392                 NaN          NaN              NaN
# 2455     Southern Africa          2.0            202.0
# 2510                 NaN          NaN              NaN
# 2588     Southern Africa          2.0            202.0
# 2643                 NaN          NaN              NaN
# 2741     Southern Africa          2.0            202.0
# 2777                 NaN          NaN              NaN
# 2920                 NaN          NaN              NaN
# 3010     Southern Africa          2.0            202.0
# 3056                 NaN          NaN              NaN
# 3173     Southern Africa          2.0            202.0
# 3183                 NaN          NaN              NaN
# 3298                 NaN          NaN              NaN
#
#       intermediate-region-code
# 430                       18.0
# 550                       18.0
# 588                        NaN
# 688                       18.0
# 795                       18.0
# 956                        NaN
# 1028                      18.0
# 1077                       NaN
# 1152                      18.0
# 1205                       NaN
# 1296                      18.0
# 1339                       NaN
# 1485                       NaN
# 1585                      18.0
# 1613                       NaN
# 1739                       NaN
# 1742                      18.0
# 1884                      18.0
# 1894                       NaN
# 1966                      18.0
# 2092                      18.0
# 2154                       NaN
# 2240                      18.0
# 2392                       NaN
# 2455                      18.0
# 2510                       NaN
# 2588                      18.0
# 2643                       NaN
# 2741                      18.0
# 2777                       NaN
# 2920                       NaN
# 3010                      18.0
# 3056                       NaN
# 3173                      18.0
# 3183                       NaN
# 3298                       NaN

# %%
col_with_country_codes = col_with_country_codes[[
    'Rank',
    'Cost of Living Index',
    'Rent Index',
    'Cost of Living Plus Rent Index',
    'Groceries Index',
    'Restaurant Price Index',
    'Local Purchasing Power Index',
    'Year',
    'Country',
    'alpha-2',
    'alpha-3',
    'region',
    'sub-region']]

# %%
col_with_country_codes.head()
# Out:
#    Rank  Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# 0     1                 126.1        85.9                           110.1
# 1     2                 123.8        71.9                           103.2
# 2     3                 120.9        77.7                           103.8
# 3     4                 117.5        78.8                           102.2
# 4     5                 112.5        33.3                            81.1
#
#    Groceries Index  Restaurant Price Index  Local Purchasing Power Index  \
# 0            154.5                   131.6                          59.8
# 1             90.1                   108.5                          41.6
# 2            115.4                   118.3                          45.5
# 3            110.9                   107.6                          55.6
# 4             99.0                    85.2                          62.8
#
#         Year      Country alpha-2 alpha-3  region       sub-region
# 0 2009-01-01      Ireland      IE     IRL  Europe  Northern Europe
# 1 2009-01-01  Netherlands      NL     NLD  Europe   Western Europe
# 2 2009-01-01       France      FR     FRA  Europe   Western Europe
# 3 2009-01-01      Belgium      BE     BEL  Europe   Western Europe
# 4 2009-01-01       Sweden      SE     SWE  Europe  Northern Europe

# %%
col_with_country_codes.to_csv(os.path.join(cwd,"cost_of_living_countries.csv"),index=False, header=[
    'rank',
    'cost_of_living_index',
    'rent_index',
    'cost_of_living_plus_rent_index',
    'groceries_index',
    'restaurant_price_index',
    'local_purchasing_power_index',
    'year',
    'country',
    'alpha_2',
    'alpha_3',
    'region',
    'sub_region'])
